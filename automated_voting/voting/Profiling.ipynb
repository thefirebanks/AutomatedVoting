# %% [markdown]
# ## Data generation code for preference profiles

# %%
from numpy import random, array, zeros, flatnonzero, genfromtxt, array_equal
from pandas import DataFrame
from svvamp import PopulationCubicUniform, PopulationEuclideanBox, PopulationGaussianWell, \
    PopulationLadder, PopulationVMFHypercircle, PopulationVMFHypersphere, PopulationSpheroid
from whalrus.profile.Profile import Profile
from whalrus.rule.RuleCondorcet import RuleCondorcet
# from whalrus.rule.RuleBorda import RuleBorda
from pickle import dump, load
from tqdm import tqdm
from whalrus.ballot.BallotOrder import BallotOrder
import argparse
import numpy as np
import random as rd

DATASET_FOLDER = "../../data"

# %%
# Add this method so that we can sort ballot objects
def __lt__(ballot1, ballot2):
    return list(ballot1) < list(ballot2)


def __gt__(ballot1, ballot2):
    return list(ballot1) > list(ballot2)


setattr(BallotOrder, "__lt__", __lt__)
setattr(BallotOrder, "__gt__", __gt__)

# %% [markdown]
# ### Profiling code
# Taken from Sebastiaan Mathôt's https://www.youtube.com/watch?v=8qEnExGLZfY and https://osf.io/upav8/

# %%
import cProfile, pstats, io

def profile(fnc):
    
    """A decorator that uses cProfile to profile a function"""
    
    def inner(*args, **kwargs):
        
        pr = cProfile.Profile()
        pr.enable()
        retval = fnc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval

    return inner

# %% [markdown]
# ### Original AV Profile Code

# %%
class AVProfile(Profile):
    def __init__(self, n_voters, origin="distribution", params="spheroid", IM_count=15, candidates=None, seed=69420):

        # Make sure we have the right input
        if origin == "distribution" and candidates is None:
            raise Exception("Candidates shouldn't be empty if we are creating a profile from distribution!")
        elif origin == "data" and params == "spheroid":
            raise Exception("Params should include csv file name, such as sample_data_profile.csv!")

        # Generate the ballots
        if origin == "distribution":

            np.random.seed(seed)

            # Create a population object
            if params == "cubic":
                pop = PopulationCubicUniform(V=n_voters, C=len(candidates))
            elif params == "euclidean":
                pop = PopulationEuclideanBox(V=n_voters, C=len(candidates), box_dimensions=[1])
            elif params == "gaussian":
                pop = PopulationGaussianWell(V=n_voters, C=len(candidates), sigma=[1], shift=[10])
            elif params == "ladder":
                pop = PopulationLadder(V=n_voters, C=len(candidates), n_rungs=5)
            elif params == "VMFHypercircle":
                pop = PopulationVMFHypercircle(V=n_voters, C=len(candidates), vmf_concentration=[10],
                                               vmf_pole=random.random_integers(0, len(candidates),
                                                                               len(candidates)))
            elif params == "VMFHypersphere":
                pop = PopulationVMFHypersphere(V=n_voters, C=len(candidates),
                                               vmf_concentration=[50, 50],
                                               vmf_probability=None,
                                               vmf_pole=[
                                                   random.random_integers(0, len(candidates), len(candidates)),
                                                   random.random_integers(0, len(candidates), len(candidates))],
                                               stretching=1)
            else:
                pop = PopulationSpheroid(V=n_voters, C=len(candidates))

            self._preferences = pop.preferences_rk
            pop.labels_candidates = self._labels_candidates = candidates

        elif origin == "data":  # params = filename
            preferences = genfromtxt(params, delimiter=',', dtype=str)
            self._labels_candidates = preferences[0, :]
            self._preferences = preferences[1:, :].astype(int)
        else:
            raise Exception("Insert either distribution or data as the parameter origin!")

        # Basic properties
        self._n_candidates = len(self._labels_candidates)
        self._n_voters = n_voters
        self._candidate_map = dict(zip(self.candidates, list(range(self.n_candidates))))

        # TODO: This could be the same array, technically!!!!!! Depending on the profile generation method
        # Get a list of possible candidates whose score we can increase, that are not the winner or the wanted candidate
        self.all_candidates_idx = [i for i in range(self.n_candidates)]

        # Get possible ranks to increase/decrease
        self.all_ranks = [i for i in range(self.n_candidates)]

        # Create a labeled version of the ranking from the population -> Allows us to initialize a Profile object
        self._candidate_rank_map = self.get_candidate_rank_map()
        self._name_ballots = self.get_named_ballots()
        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self._name_ballots]

        # Create a profile object - automatically creates ordered ballots
        super().__init__(self._name_ballots)

        # Sort everything we have so far for ease of index accesing
        #         self.ballots.sort()
        #         self._name_ballots.sort()

        # Create a dataframe of ballots and how many people voted for them
        self._ballot_df = self.to_ballot_dataframe()

        # TODO: Modify all of these so that they use BALLOTS instead of preferences
        # Create a dataframe representation of the profile so we can print it out
        self._rank_matrix = self.to_count_matrix()
        self._rank_df = self.to_count_dataframe()
        # self._tournament_matrix = self.to_tournament_matrix()

        # Create one-hot vectors of established candidates (Condorcet, Majority, etc.)
        self._condorcet_w, self._condorcet_w_vector = self.get_condorcet()
        self._majority_w, self._majority_w_vector = self.get_majority()
        self._plurality_w, self._plurality_w_vector = self.get_plurality()

        # Extra variable to keep track of IM modified profiles - A set of tuples
        self._IM_pairs_set = set()

        # Extra variable to keep track of whether we have repeated matrices within the simulations
        self._repeated_rank_matrices = 0

        # Create a sample of simulated profiles for IM
        # TODO This could be simply the list of ballots and we update rank matrix later!!!!!!!!!!!
        self._IM_rank_matrices, self._IM_ballots = self.create_IM(count=IM_count)

        # Create a sample of simulated profiles for IIA
        # self._IIA_profiles = self.create_IIA_dict()

    # Basic properties
    @property
    def n_candidates(self):
        return self._n_candidates

    @property
    def candidate_map(self):
        return self._candidate_map

    @property
    def n_voters(self):
        return self._n_voters

    @property
    def candidates(self):
        return self._labels_candidates

    # Ballots and Profile matrix/dataframe formats
    @property
    def rank_matrix(self):
        self._rank_matrix = self.to_count_matrix()
        return self._rank_matrix

    # @property
    # def tournament_matrix(self):
    #     self._tournament_matrix = self.to_tournament_matrix()
    #     return self._tournament_matrix

    @property
    def rank_df(self):
        self._rank_df = self.to_count_dataframe()
        return self._rank_df

    # Ballot descriptors
    @property
    def name_ballots(self):
        self._name_ballots = [list(ballot) for ballot in self.ballots]
        return self._name_ballots

    @property
    def idx_ballots(self):
        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self.name_ballots]
        return self._idx_ballots

    @property
    def ranked_ballots_map(self):
        return self._candidate_rank_map

    @property
    def ballot_df(self):
        self._ballot_df = self.to_ballot_dataframe()
        return self._ballot_df

    # Profile special candidates (strings and vectors
    @property
    def condorcet_w(self):
        return self._condorcet_w

    @property
    def condorcet_w_vector(self):
        return self._condorcet_w_vector

    @property
    def majority_w(self):
        return self._majority_w

    @property
    def majority_w_vector(self):
        return self._majority_w_vector

    @property
    def plurality_w(self):
        return self._plurality_w

    @property
    def plurality_w_vector(self):
        return self._plurality_w_vector

    # Simulated profiles for IM
    @property
    def IM_rank_matrices(self):
        return self._IM_rank_matrices

    @property
    def IM_ballots(self):
        return self._IM_ballots

    def flatten_rank_matrix(self, rank_matrix=None) -> array:
        """
            Input matrix for neural network
            - Flatten dataset for network input layer purposes
            - Reshape to (n_features, 1) for tensor input, then transpose to make it n_features columns,
               where n_features = n_candidates**2 """

        if rank_matrix is None:
            return self.rank_matrix.flatten('F').reshape(self.n_candidates * self.n_candidates, 1).T
        else:
            return rank_matrix.flatten('F').reshape(self.n_candidates * self.n_candidates, 1).T

    def get_condorcet(self) -> (str, array):
        """ Check if a profile contains a condorcet winner and returns a one-hot vector representing them.
            Returns:
                - The name of the winner as a string, or "No Condorcet Winner" otherwise
                - A numpy array of size n_candidates, where candidate i is 1 if they are a Condorcet winner,
                and the rest are 0. If there is no Condorcet winner, then all elements are 0
                 """

        condorcet = RuleCondorcet(self)

        if len(condorcet.cowinners_) == 1:
            winner = next(iter(condorcet.cowinners_))
            winner_idx = self.candidates.index(winner)

            one_hot = zeros(shape=(self.n_candidates,))
            one_hot[winner_idx] = 1

            return winner, one_hot

        return "No Condorcet Winner", zeros(shape=(self.n_candidates,))

    def get_majority(self) -> (str, array):
        """ Check if a profile contains a majority winner and returns a one-hot vector representing them.
            Returns:
                - The name of the winner as a string, or "No Majority Winner" otherwise
                - A numpy array of size n_candidates, where candidate i is 1 if they are a majority winner,
                and the rest are 0. If there is no majority winner, then all elements are 0 """

        # Get the first row as those are the counts for how many times a candidate was ranked first
        first_candidates = self.rank_matrix[0]

        for candidate_idx, candidate_votes in enumerate(first_candidates):
            if candidate_votes >= 0.5 * self.n_voters:
                one_hot = zeros(shape=(self.n_candidates,))
                one_hot[candidate_idx] = 1
                return self.candidates[candidate_idx], one_hot

        return "No Majority Winner", zeros(shape=(self.n_candidates,))

    # TODO: Instead of returning one of the candidates with equal probability,
    #  return the one with the most second choice votes!!!!!! OR most votes recursively
    def get_plurality(self) -> (str, array):
        """ Returns the plurality winner of a given profile. If there are ties, it randomly returns one of the candidates
            with equal probability

            Returns:
                - The name of the winner
                - A numpy array of size n_candidates, where candidate i is 1 if they are a majority winner,
                and the rest are 0 """

        # Get the plurality winner from the first row of the rank matrix, break ties randomly
        winner_idx = random.choice(flatnonzero(self.rank_matrix[0] == self.rank_matrix[0].max()))
        winner = self.candidates[winner_idx]

        # Get the one-hot vector
        one_hot = zeros(shape=(self.n_candidates,))
        one_hot[winner_idx] = 1

        return winner, one_hot

    def get_candidate_rank_map(self) -> list:
        """ Convert profile to a list of {candidate: rank} per voter
            This method should only be used at initialization of the profile """

        ordered_prof = []

        for ballot in self._preferences:
            ordered_ballot = {}
            for candidate, rank in zip(self._labels_candidates, ballot):
                ordered_ballot[candidate] = rank

            ordered_prof.append(ordered_ballot)

        sorted_dicts = [dict(sorted(profile.items(), key=lambda kv: kv[1])) for profile in ordered_prof]

        return sorted_dicts

    def get_named_ballots(self) -> list:
        return [list(m.keys()) for m in self._candidate_rank_map]

    # def to_tournament_matrix(self) -> array:
    #     return array([])

    def to_count_matrix(self) -> array:
        """ Create a matrix representation of the profile,
        where matrix[c][r] represent the frequency of candidate c in rank r """

        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self.name_ballots]

        matrix_rank = [[0] * len(self._idx_ballots[0]) for _ in self._idx_ballots[0]]

        for ballot in self._idx_ballots:
            for candidate, rank in enumerate(ballot):
                matrix_rank[candidate][rank] += 1

        return array(matrix_rank).T

    def to_count_dataframe(self) -> DataFrame:
        """ Creates a dataframe representation of the profile from the matrix representation """
        data_dict = dict()
        self._rank_matrix = self.to_count_matrix()

        # Create dictionary for dataframe
        for i in range(len(self._rank_matrix)):
            data_dict[f"Rank {i + 1}"] = self._rank_matrix[:, i]

        df = DataFrame(data_dict, index=self.candidates)

        return df

    def to_ballot_dataframe(self) -> DataFrame:
        """ Creates a dataframe where the columns represent the ballots and the top row represents
        the number of candidates that voted for a particular candiate """

        # {Ballot: # of people that have it}
        ballot_counts = dict()
        for ballot in self.name_ballots:
            ballot_str = tuple(ballot)
            if ballot_str in ballot_counts:
                ballot_counts[ballot_str] += 1
            else:
                ballot_counts[ballot_str] = 1

        # Now, build the dataframe
        header = []
        rows = []

        # Get the candidates as their index
        for ballot, count in ballot_counts.items():
            # The count will be the header
            header.append(count)
            rows.append(ballot)

        # We will transpose the rows to format ballots properly
        columns = array(rows).T
        df = DataFrame(columns, columns=header)

        return df

    def new_ballots(self, c_down, c_up, c_down_rank, c_up_rank):
        """
        Given two candidates c_down, c_up and two ranks c_down_rank, c_up_rank, we want to find the first ballot
        that has c_down in c_down rank and c_up in c_up_rank, and switch them. This will update the list of ballots
        with a new BallotOrder object.
        """
        self._name_ballots = [list(ballot) for ballot in self.ballots]
        new_ballots = [ballot for ballot in self.ballots]
        c_down, c_up = self.candidates[c_down], self.candidates[c_up]

        # For every ballot that we have, check if it is in the ordering that we want
        for i in range(len(self._name_ballots)):

            if self._candidate_rank_map[i][c_up] == c_up_rank and self._candidate_rank_map[i][c_down] == c_down_rank:
                new_ballot_l = [c for c in self._name_ballots[i]]

                # Swap candidates at a given position
                new_ballot_l[c_up_rank], new_ballot_l[c_down_rank] = c_down, c_up

                # Create a new ballot order obj and replace!
                new_ballots[i] = BallotOrder(new_ballot_l)
                break

        return new_ballots

    def create_IM(self, count=20) -> (dict, dict):
        IM_rank_matrices = dict()
        IM_ballots = dict()

        # Make sure we have the right, original matrix
        self._rank_matrix = self.to_count_matrix()

        for possible_winner in range(self.n_candidates):
            # print(f"Generating alternative IM profiles for candidate {self.candidates[possible_winner]}...")

            self._IM_pairs_set = set()
            IM_rank_matrices[possible_winner], IM_ballots[possible_winner] = self.generate_IM_profiles(possible_winner,
                                                                                                       count)

        return IM_rank_matrices, IM_ballots

    def generate_IM_profiles(self, winner_idx, count) -> (list, list):
        IM_rank_matrices = []
        IM_ballots = []

        wanted_candidates = [i for i in range(self.n_candidates) if i != winner_idx]

        for alt_candidate in wanted_candidates:
            for i in range(count):
                IM_profile, c_up, c_up_rank, c_down, c_down_rank = self.generate_IM_rank_matrix(alt_candidate,
                                                                                                winner_idx)

                # Make sure that we only add profiles that are not equal to the original profile
                if not array_equal(IM_profile, self._rank_matrix):
                    IM_rank_matrices.append(IM_profile)
                    IM_ballots.append(self.new_ballots(c_down, c_up, c_down_rank, c_up_rank))

        return IM_rank_matrices, IM_ballots

    def generate_IM_rank_matrix(self, wanted_idx, winner_idx):

        # Deep copy the rank matrix to avoid modifying the original one
        new_rank_matrix = self._rank_matrix.copy()
        option, i = 1, 0

        while True:
#             random.seed(random.choice(range(9999)))

            # Generate rank/candidate_idx pairs to modify the rank matrix
            (candidate_down_rank, candidate_down), (candidate_up_rank, candidate_up) = \
                self.generate_IM_rank_pairs(wanted_idx, winner_idx, option=option)

            # If we have found a good alternative profile, great! Else we just keep looking for one
            # What is a good alternative profile?
            # 1. We haven't chosen this pair already
            # 2. There is at least 1 person that voted for candidate up/down in a particular rank (No 0s in rank matrix)
            if (candidate_down_rank, candidate_down) not in self._IM_pairs_set and \
                (candidate_up_rank, candidate_up) not in self._IM_pairs_set and \
                new_rank_matrix[candidate_up_rank, candidate_up] != 0 and \
                new_rank_matrix[candidate_down_rank, candidate_down] != 0:

                self._IM_pairs_set.add((candidate_down_rank, candidate_down))
                self._IM_pairs_set.add((candidate_up_rank, candidate_up))
                break

            # This is to make sure we don't loop forever if we run out of alternative profiles to generate
            i += 1
            if i % 50 == 0:
                option += 1
            if option > 3:
                return new_rank_matrix, -1, -1, -1, -1

        # Perform operations
        new_rank_matrix[candidate_up_rank, candidate_up] -= 1
        new_rank_matrix[candidate_down_rank, candidate_down] -= 1

        new_rank_matrix[candidate_up_rank, candidate_down] += 1
        new_rank_matrix[candidate_down_rank, candidate_up] += 1

        return new_rank_matrix, candidate_up, candidate_up_rank, candidate_down, candidate_down_rank

    def generate_IM_rank_pairs(self, wanted_idx, winner_idx, option=1) -> (tuple, tuple):
        """ Given a winner candidate, and a wanted candidate != winner candidate for a particular voter,
            return an alternative rank_matrix reflecting a non-truthful ballot from that voter

            - wanted_candidate = int, the index of a non-winner preferred candidate
            - winner_candidate = int, the index of the winner candidate for a particular rank_matrix
            @param: option = int representing the type of modification to the profile we will make

            @returns: alt_rank_matrix = 2D np.array representing an alternative rank_matrix """


        # TODO: DEAL WITH ZEROS IN THE MATRIX!!!!!!!!!!!!!!!!!!!!!!!!!!!!! So we don't end up with negative ranks

        # Choose random non-winner/non-wanted candidates to alter their rank - Make sure we don't choose the same candidate
        candidate_down = random.choice(self.all_candidates_idx)
        candidate_up = random.choice(
            self.all_candidates_idx[:candidate_down] + self.all_candidates_idx[candidate_down + 1:])

        # Get the random ranks to modify scores from - Also make sure we don't choose the same number
        candidate_down_rank = random.choice(self.all_ranks)
        candidate_up_rank = random.choice(
            self.all_ranks[:candidate_down_rank] + self.all_ranks[candidate_down_rank + 1:])

        # Exclude candidate W from the list of candidates going up
        if option == 1:
            # C > O_1 > O_2 > W ===> C > O_2 > O_1 > W
            candidate_up = random.choice(
                self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:])
            candidate_down = random.choice(
                self.all_candidates_idx[:candidate_up] + self.all_candidates_idx[candidate_up + 1:])

        # Select candidate W to go down
        elif option == 2:
            # C > W > O ===> C > O > W
            candidate_down = winner_idx
            candidate_up = random.choice(
                self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:])

        # Exclude candidate C from the list of candidates going down
        elif option == 3:
            candidate_down = random.choice(
                self.all_candidates_idx[:wanted_idx] + self.all_candidates_idx[wanted_idx + 1:])
            candidate_up = random.choice(
                self.all_candidates_idx[:candidate_down] + self.all_candidates_idx[candidate_down + 1:])

        return (candidate_down_rank, candidate_down), (candidate_up_rank, candidate_up)

    def generate_IIA_profiles(self, count) -> array:
        return array

# %% [markdown]
# ### New AV Profile Code

# %%
class AVProfile(Profile):
    def __init__(self, n_voters, origin="distribution", params="spheroid", IM_count=15, candidates=None, seed=69420):

        # Make sure we have the right input
        if origin == "distribution" and candidates is None:
            raise Exception("Candidates shouldn't be empty if we are creating a profile from distribution!")
        elif origin == "data" and params == "spheroid":
            raise Exception("Params should include csv file name, such as sample_data_profile.csv!")

        # Generate the ballots
        if origin == "distribution":

#             np.random.seed(seed)

            # Create a population object
            if params == "cubic":
                pop = PopulationCubicUniform(V=n_voters, C=len(candidates))
            elif params == "euclidean":
                pop = PopulationEuclideanBox(V=n_voters, C=len(candidates), box_dimensions=[1])
            elif params == "gaussian":
                pop = PopulationGaussianWell(V=n_voters, C=len(candidates), sigma=[1], shift=[10])
            elif params == "ladder":
                pop = PopulationLadder(V=n_voters, C=len(candidates), n_rungs=5)
            elif params == "VMFHypercircle":
                pop = PopulationVMFHypercircle(V=n_voters, C=len(candidates), vmf_concentration=[10],
                                               vmf_pole=random.random_integers(0, len(candidates),
                                                                               len(candidates)))
            elif params == "VMFHypersphere":
                pop = PopulationVMFHypersphere(V=n_voters, C=len(candidates),
                                               vmf_concentration=[50, 50],
                                               vmf_probability=None,
                                               vmf_pole=[
                                                   random.random_integers(0, len(candidates), len(candidates)),
                                                   random.random_integers(0, len(candidates), len(candidates))],
                                               stretching=1)
            else:
                pop = PopulationSpheroid(V=n_voters, C=len(candidates))

            self._preferences = pop.preferences_rk
            pop.labels_candidates = self._labels_candidates = candidates

        elif origin == "data":  # params = filename
            preferences = genfromtxt(params, delimiter=',', dtype=str)
            self._labels_candidates = preferences[0, :]
            self._preferences = preferences[1:, :].astype(int)
        else:
            raise Exception("Insert either distribution or data as the parameter origin!")

        # Basic properties
        self._n_candidates = len(self._labels_candidates)
        self._n_voters = n_voters
        
        self._candidate_map = dict(zip(self.candidates, list(range(self.n_candidates))))

        # TODO: This could be the same array, technically!!!!!! Depending on the profile generation method
        # Get a list of possible candidates whose score we can increase, that are not the winner or the wanted candidate
        self.all_candidates_idx = list(range(self.n_candidates))

        # Get possible ranks to increase/decrease
#         self.all_ranks = [i for i in range(self.n_candidates)]

        # Create a labeled version of the ranking from the population -> Allows us to initialize a Profile object
        self._candidate_rank_map = self.get_candidate_rank_map()
        self._name_ballots = self.get_named_ballots()
        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self._name_ballots]

        # Create a profile object - automatically creates ordered ballots
        super().__init__(self._name_ballots)

        # Sort everything we have so far for ease of index accesing
        #         self.ballots.sort()
        #         self._name_ballots.sort()

        # Create a dataframe of ballots and how many people voted for them
        self._ballot_df = self.to_ballot_dataframe()

        # TODO: Modify all of these so that they use BALLOTS instead of preferences
        # Create a dataframe representation of the profile so we can print it out
        self._rank_matrix = self.to_count_matrix()
        self._rank_df = self.to_count_dataframe()
        # self._tournament_matrix = self.to_tournament_matrix()

        # Create one-hot vectors of established candidates (Condorcet, Majority, etc.)
        self._condorcet_w, self._condorcet_w_vector = self.get_condorcet()
        self._majority_w, self._majority_w_vector = self.get_majority()
        self._plurality_w, self._plurality_w_vector = self.get_plurality()

        # Extra variable to keep track of IM modified profiles - A set of tuples
        self._IM_pairs_set = set()

        # Extra variable to keep track of whether we have repeated matrices within the simulations
        self._repeated_rank_matrices = 0

        # Create a sample of simulated profiles for IM
        # TODO This could be simply the list of ballots and we update rank matrix later!!!!!!!!!!!
        self._IM_rank_matrices, self._IM_ballots = self.create_IM(count=IM_count)

        # Create a sample of simulated profiles for IIA
        # self._IIA_profiles = self.create_IIA_dict()

    # Basic properties
    @property
    def n_candidates(self):
        return self._n_candidates

    @property
    def candidate_map(self):
        return self._candidate_map

    @property
    def n_voters(self):
        return self._n_voters

    @property
    def candidates(self):
        return self._labels_candidates

    # Ballots and Profile matrix/dataframe formats
    @property
    def rank_matrix(self):
        self._rank_matrix = self.to_count_matrix()
        return self._rank_matrix

    # @property
    # def tournament_matrix(self):
    #     self._tournament_matrix = self.to_tournament_matrix()
    #     return self._tournament_matrix

    @property
    def rank_df(self):
        self._rank_df = self.to_count_dataframe()
        return self._rank_df

    # Ballot descriptors
    @property
    def name_ballots(self):
        self._name_ballots = [list(ballot) for ballot in self.ballots]
        return self._name_ballots

    @property
    def idx_ballots(self):
        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self.name_ballots]
        return self._idx_ballots

    @property
    def ranked_ballots_map(self):
        return self._candidate_rank_map

    @property
    def ballot_df(self):
        self._ballot_df = self.to_ballot_dataframe()
        return self._ballot_df

    # Profile special candidates (strings and vectors
    @property
    def condorcet_w(self):
        return self._condorcet_w

    @property
    def condorcet_w_vector(self):
        return self._condorcet_w_vector

    @property
    def majority_w(self):
        return self._majority_w

    @property
    def majority_w_vector(self):
        return self._majority_w_vector

    @property
    def plurality_w(self):
        return self._plurality_w

    @property
    def plurality_w_vector(self):
        return self._plurality_w_vector

    # Simulated profiles for IM
    @property
    def IM_rank_matrices(self):
        return self._IM_rank_matrices

    @property
    def IM_ballots(self):
        return self._IM_ballots

    def flatten_rank_matrix(self, rank_matrix=None) -> array:
        """
            Input matrix for neural network
            - Flatten dataset for network input layer purposes
            - Reshape to (n_features, 1) for tensor input, then transpose to make it n_features columns,
               where n_features = n_candidates**2 """

        if rank_matrix is None:
            return self.rank_matrix.flatten('F').reshape(self.n_candidates * self.n_candidates, 1).T
        else:
            return rank_matrix.flatten('F').reshape(self.n_candidates * self.n_candidates, 1).T

    def get_condorcet(self) -> (str, array):
        """ Check if a profile contains a condorcet winner and returns a one-hot vector representing them.
            Returns:
                - The name of the winner as a string, or "No Condorcet Winner" otherwise
                - A numpy array of size n_candidates, where candidate i is 1 if they are a Condorcet winner,
                and the rest are 0. If there is no Condorcet winner, then all elements are 0
                 """

        condorcet = RuleCondorcet(self)

        if len(condorcet.cowinners_) == 1:
            winner = next(iter(condorcet.cowinners_))
            winner_idx = self.candidates.index(winner)

            one_hot = zeros(shape=(self.n_candidates,))
            one_hot[winner_idx] = 1

            return winner, one_hot

        return "No Condorcet Winner", zeros(shape=(self.n_candidates,))

    def get_majority(self) -> (str, array):
        """ Check if a profile contains a majority winner and returns a one-hot vector representing them.
            Returns:
                - The name of the winner as a string, or "No Majority Winner" otherwise
                - A numpy array of size n_candidates, where candidate i is 1 if they are a majority winner,
                and the rest are 0. If there is no majority winner, then all elements are 0 """

        # Get the first row as those are the counts for how many times a candidate was ranked first
        first_candidates = self.rank_matrix[0]

        for candidate_idx, candidate_votes in enumerate(first_candidates):
            if candidate_votes >= 0.5 * self.n_voters:
                one_hot = zeros(shape=(self.n_candidates,))
                one_hot[candidate_idx] = 1
                return self.candidates[candidate_idx], one_hot

        return "No Majority Winner", zeros(shape=(self.n_candidates,))

    # TODO: Instead of returning one of the candidates with equal probability,
    #  return the one with the most second choice votes!!!!!! OR most votes recursively
    def get_plurality(self) -> (str, array):
        """ Returns the plurality winner of a given profile. If there are ties, it randomly returns one of the candidates
            with equal probability

            Returns:
                - The name of the winner
                - A numpy array of size n_candidates, where candidate i is 1 if they are a majority winner,
                and the rest are 0 """

        # Get the plurality winner from the first row of the rank matrix, break ties randomly
        winner_idx = random.choice(flatnonzero(self.rank_matrix[0] == self.rank_matrix[0].max()))
        winner = self.candidates[winner_idx]

        # Get the one-hot vector
        one_hot = zeros(shape=(self.n_candidates,))
        one_hot[winner_idx] = 1

        return winner, one_hot

    def get_candidate_rank_map(self) -> list:
        """ Convert profile to a list of {candidate: rank} per voter
            This method should only be used at initialization of the profile """

        ordered_prof = []

        for ballot in self._preferences:
            ordered_ballot = {}
            for candidate, rank in zip(self._labels_candidates, ballot):
                ordered_ballot[candidate] = rank

            ordered_prof.append(ordered_ballot)

        sorted_dicts = [dict(sorted(profile.items(), key=lambda kv: kv[1])) for profile in ordered_prof]

        return sorted_dicts

    def get_named_ballots(self) -> list:
        return [list(m.keys()) for m in self._candidate_rank_map]

    # def to_tournament_matrix(self) -> array:
    #     return array([])

    def to_count_matrix(self) -> array:
        """ Create a matrix representation of the profile,
        where matrix[c][r] represent the frequency of candidate c in rank r """

        self._idx_ballots = [[self.candidate_map[c] for c in ballot] for ballot in self.name_ballots]

        matrix_rank = [[0] * len(self._idx_ballots[0]) for _ in self._idx_ballots[0]]

        for ballot in self._idx_ballots:
            for candidate, rank in enumerate(ballot):
                matrix_rank[candidate][rank] += 1

        return array(matrix_rank).T

    def to_count_dataframe(self) -> DataFrame:
        """ Creates a dataframe representation of the profile from the matrix representation """
        data_dict = dict()
        self._rank_matrix = self.to_count_matrix()

        # Create dictionary for dataframe
        for i in range(len(self._rank_matrix)):
            data_dict[f"Rank {i + 1}"] = self._rank_matrix[:, i]

        df = DataFrame(data_dict, index=self.candidates)

        return df

    def to_ballot_dataframe(self) -> DataFrame:
        """ Creates a dataframe where the columns represent the ballots and the top row represents
        the number of candidates that voted for a particular candiate """

        # {Ballot: # of people that have it}
        ballot_counts = dict()
        for ballot in self.name_ballots:
            ballot_str = tuple(ballot)
            if ballot_str in ballot_counts:
                ballot_counts[ballot_str] += 1
            else:
                ballot_counts[ballot_str] = 1

        # Now, build the dataframe
        header = []
        rows = []

        # Get the candidates as their index
        for ballot, count in ballot_counts.items():
            # The count will be the header
            header.append(count)
            rows.append(ballot)

        # We will transpose the rows to format ballots properly
        columns = array(rows).T
        df = DataFrame(columns, columns=header)

        return df

    def new_ballots(self, c_down, c_up, c_down_rank, c_up_rank):
        """
        Given two candidates c_down, c_up and two ranks c_down_rank, c_up_rank, we want to find the first ballot
        that has c_down in c_down rank and c_up in c_up_rank, and switch them. This will update the list of ballots
        with a new BallotOrder object.
        """
        self._name_ballots = [list(ballot) for ballot in self.ballots]
        new_ballots = [ballot for ballot in self.ballots]
        c_down, c_up = self.candidates[c_down], self.candidates[c_up]

        # For every ballot that we have, check if it is in the ordering that we want
        for i in range(len(self._name_ballots)):

            if self._candidate_rank_map[i][c_up] == c_up_rank and self._candidate_rank_map[i][c_down] == c_down_rank:
                new_ballot_l = [c for c in self._name_ballots[i]]

                # Swap candidates at a given position
                new_ballot_l[c_up_rank], new_ballot_l[c_down_rank] = c_down, c_up

                # Create a new ballot order obj and replace!
                new_ballots[i] = BallotOrder(new_ballot_l)
                break

        return new_ballots

    def create_IM(self, count) -> (dict, dict):
        IM_rank_matrices = dict()
        IM_ballots = dict()

        # Make sure we have the right, original matrix
        self._rank_matrix = self.to_count_matrix()

        for possible_winner in range(self.n_candidates):
            # print(f"Generating alternative IM profiles for candidate {self.candidates[possible_winner]}...")

            self._IM_pairs_set = set()
            IM_rank_matrices[possible_winner], IM_ballots[possible_winner] = self.generate_IM_profiles(possible_winner,
                                                                                                       count)

        return IM_rank_matrices, IM_ballots

    def generate_IM_profiles(self, winner_idx, count) -> (list, list):
        IM_rank_matrices = []
        IM_ballots = []
        badcount = 0
        wanted_candidates = [i for i in range(self.n_candidates) if i != winner_idx]

        for alt_candidate in wanted_candidates:
            for i in range(count):
                IM_profile, c_up, c_up_rank, c_down, c_down_rank = self.generate_IM_rank_matrix(alt_candidate,
                                                                                                winner_idx)

                # Make sure that we only add profiles that are not equal to the original profile
                if not array_equal(IM_profile, self._rank_matrix):
#                     print("Here a certain number of times...")
                    IM_rank_matrices.append(IM_profile)
                    IM_ballots.append(self.new_ballots(c_down, c_up, c_down_rank, c_up_rank))
                else:
                    badcount += 1
        print(badcount)
        return IM_rank_matrices, IM_ballots

    def generate_IM_rank_matrix(self, wanted_idx, winner_idx):

        # Deep copy the rank matrix to avoid modifying the original one
        new_rank_matrix = self._rank_matrix.copy()
        option, i = 1, 0

        while True:

            # Generate rank/candidate_idx pairs to modify the rank matrix
            (candidate_down_rank, candidate_down), (candidate_up_rank, candidate_up) = \
                self.generate_IM_rank_pairs(wanted_idx, winner_idx, option=option)

            # If we have found a good alternative profile, great! Else we just keep looking for one
            # What is a good alternative profile?
            # 1. We haven't chosen this pair already
            # 2. There is at least 1 person that voted for candidate up/down in a particular rank (No 0s in rank matrix)
            if (candidate_down_rank, candidate_down) not in self._IM_pairs_set and \
                (candidate_up_rank, candidate_up) not in self._IM_pairs_set and \
                new_rank_matrix[candidate_up_rank, candidate_up] != 0 and \
                new_rank_matrix[candidate_down_rank, candidate_down] != 0:

                self._IM_pairs_set.add((candidate_down_rank, candidate_down))
                self._IM_pairs_set.add((candidate_up_rank, candidate_up))
                break

            # This is to make sure we don't loop forever if we run out of alternative profiles to generate
            i += 1
#             if i % 50 == 0:
#                 option += 1
#                 option %= 3
            if i == 100:
                return new_rank_matrix, -1, -1, -1, -1

        # Perform operations
        new_rank_matrix[candidate_up_rank, candidate_up] -= 1
        new_rank_matrix[candidate_down_rank, candidate_down] -= 1

        new_rank_matrix[candidate_up_rank, candidate_down] += 1
        new_rank_matrix[candidate_down_rank, candidate_up] += 1

        return new_rank_matrix, candidate_up, candidate_up_rank, candidate_down, candidate_down_rank

    def generate_IM_rank_pairs(self, wanted_idx, winner_idx, option=1) -> (tuple, tuple):
        """ Given a winner candidate, and a wanted candidate != winner candidate for a particular voter,
            return an alternative rank_matrix reflecting a non-truthful ballot from that voter

            - wanted_candidate = int, the index of a non-winner preferred candidate
            - winner_candidate = int, the index of the winner candidate for a particular rank_matrix
            @param: option = int representing the type of modification to the profile we will make

            @returns: alt_rank_matrix = 2D np.array representing an alternative rank_matrix """


        # TODO: DEAL WITH ZEROS IN THE MATRIX!!!!!!!!!!!!!!!!!!!!!!!!!!!!! So we don't end up with negative ranks

        # Choose random non-winner/non-wanted candidates to alter their rank - Make sure we don't choose the same candidate
#         candidate_down = random.choice(self.all_candidates_idx)
#         candidate_up = random.choice(
#             self.all_candidates_idx[:candidate_down] + self.all_candidates_idx[candidate_down + 1:])
        
        samples = rd.sample(self.all_candidates_idx, 2)
        candidate_down, candidate_up = samples[0], samples[1]

        samples = rd.sample(self.all_candidates_idx, 2)
        candidate_down_rank, candidate_up_rank = samples[0], samples[1]
        
        # Get the random ranks to modify scores from - Also make sure we don't choose the same number
#         candidate_down_rank = random.choice(self.all_ranks)
#         candidate_up_rank = random.choice(
#             self.all_ranks[:candidate_down_rank] + self.all_ranks[candidate_down_rank + 1:])

        # List of probabilities for a candidate to be chosen, it is uniform at the beginning
#         probs = [1/(len(self.all_candidates_idx)-1)]*len(self.all_candidates_idx)

#         # Exclude candidate W from the list of candidates going up
#         # C > O_1 > O_2 > W ===> C > O_2 > O_1 > W
#         if option == 1:
#             candidate_up = rd.sample(self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:], 1)[0]
#             candidate_down = rd.sample(self.all_candidates_idx[:candidate_up] + self.all_candidates_idx[candidate_up + 1:], 1)[0]
#             # Everyone except W has equal probability of going up
# #             probs[winner_idx] = 0
# #             candidate_up = random.choice(self.all_candidates_idx, p=probs)

            # Now W has equal probability of going down as everyone else except the candidate that we chose earlier
#             probs[winner_idx] = 1/(len(self.all_candidates_idx)-1)
#             probs[candidate_up] = 0
#             candidate_down = random.choice(self.all_candidates_idx, p=probs)

#         # Select candidate W to go down
#         # C > W > O ===> C > O > W
        # Select candidate W to go down
#         elif option == 2:
#             # C > W > O ===> C > O > W
#             candidate_down = winner_idx
#             candidate_up = rd.sample(self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:], 1)[0]

#         # Exclude candidate C from the list of candidates going down
#         elif option == 3:
#             candidate_down = rd.sample(self.all_candidates_idx[:wanted_idx] + self.all_candidates_idx[wanted_idx + 1:], 1)[0]
#             candidate_up = rd.sample(self.all_candidates_idx[:candidate_down] + self.all_candidates_idx[candidate_down + 1:], 1)[0]
# #             candidate_down = winner_idx

# #             # Everyone except W has equal probability of going up
#             probs[winner_idx] = 0
#             candidate_up = random.choice(self.all_candidates_idx, p=probs)

#         # Exclude candidate C from the list of candidates going down
#         elif option == 3:
#             probs[wanted_idx] = 0
#             candidate_down = random.choice(self.all_candidates_idx, p=probs)

#             probs[candidate_down] = 0
#             probs[wanted_idx] = 1/(len(self.all_candidates_idx)-1)
#             candidate_up = random.choice(self.all_candidates_idx, p=probs)

        return (candidate_down_rank, candidate_down), (candidate_up_rank, candidate_up)

    def generate_IIA_profiles(self, count) -> array:
        return array

# %% [markdown]
# ### Parameters

# %%
candidates = ["Austin", "Brock", "Chad", "Derek", "Ethan", "Gabe", "Jack", "Liam", "Mike", "Tyler"]
distributions = ["spheroid", "cubic", "euclidean", "gaussian", "ladder", "VMFHypercircle", "VMFHypersphere"]

n_profiles = 1
n_voters = 20
n_candidates = 3
n_dists = 1
n_im = 100
seed = 69420
candidates = candidates[:n_candidates]
dists = distributions[:n_dists]

# %%
@profile
def generate_profile_dataset(num_profiles, n_voters, candidates, origin, params, IM_count, r_seed):
    # Choose a random seed every time
    np.random.seed(r_seed)
#     seeds = list(range(99999))
#     np.random.shuffle(seeds)

    dataset = []

    for i in tqdm(range(num_profiles)):
#         seed = seeds.pop()
        dataset.append(AVProfile(n_voters, origin=origin, params=params, candidates=candidates, IM_count=IM_count, seed=seed))
    return dataset

# %%
for distribution in dists:
    print("==========================================")
    print(f"\nGenerating {distribution} dataset...\n")
    print("==========================================")

    dataset = generate_profile_dataset(n_profiles, n_voters, candidates,
                                       "distribution", distribution, n_im, seed)
#     store_dataset(dataset, n_candidates, n_voters, n_profiles, distribution, n_im)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ==========================================
#
# Generating spheroid dataset...
#
# ==========================================
# 196
# 196
# 100%|██████████| 1/1 [00:01<00:00,  1.18s/it]
# 196
#          1883296 function calls (1882816 primitive calls) in 1.191 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.191    1.191 <ipython-input-272-851044307fd7>:1(generate_profile_dataset)
#         1    0.000    0.000    1.176    1.176 <ipython-input-274-c59bfe7bbe66>:2(__init__)
#         1    0.000    0.000    1.171    1.171 <ipython-input-274-c59bfe7bbe66>:364(create_IM)
#         3    0.003    0.001    1.171    0.390 <ipython-input-274-c59bfe7bbe66>:380(generate_IM_profiles)
#       600    0.070    0.000    1.139    0.002 <ipython-input-274-c59bfe7bbe66>:401(generate_IM_rank_matrix)
#     58854    0.080    0.000    1.028    0.000 <ipython-input-274-c59bfe7bbe66>:443(generate_IM_rank_pairs)
#    117708    0.369    0.000    0.948    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/random.py:286(sample)
#    235416    0.221    0.000    0.321    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/random.py:224(_randbelow)
#    236492    0.117    0.000    0.247    0.000 {built-in method builtins.isinstance}
#    235457    0.057    0.000    0.129    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/abc.py:137(__instancecheck__)
#    392575    0.075    0.000    0.075    0.000 {method 'getrandbits' of '_random.Random' objects}
#    235457    0.073    0.000    0.073    0.000 {built-in method _abc._abc_instancecheck}
#       600    0.041    0.000    0.041    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       600    0.002    0.000    0.026    0.000 <__array_function__ internals>:2(array_equal)
#    235416    0.025    0.000    0.025    0.000 {method 'bit_length' of 'int' objects}
#   605/603    0.001    0.000    0.024    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       600    0.014    0.000    0.023    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numeric.py:2287(array_equal)
#         3    0.000    0.000    0.013    0.004 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1417(display)
# 118309/118270    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#         7    0.000    0.000    0.011    0.002 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:336(flush)
#         2    0.000    0.000    0.010    0.005 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1074(__iter__)
#         7    0.000    0.000    0.010    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.010    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:264(wait)
#        75    0.010    0.000    0.010    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.010    0.003 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:303(print_status)
#         3    0.000    0.000    0.010    0.003 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:297(fp_write)
#         2    0.000    0.000    0.008    0.004 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1235(close)
#       600    0.001    0.000    0.006    0.000 {method 'all' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.006    0.003 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1289(refresh)
#       600    0.000    0.000    0.006    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_methods.py:47(_all)
#       604    0.005    0.000    0.005    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        40    0.000    0.000    0.004    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:197(schedule)
#         1    0.000    0.000    0.004    0.004 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:784(__init__)
#        40    0.004    0.000    0.004    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/zmq/sugar/socket.py:342(send)
#        15    0.000    0.000    0.003    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:384(write)
#         4    0.000    0.000    0.003    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1397(moveto)
#      1810    0.001    0.000    0.003    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_asarray.py:16(asarray)
#      1829    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.002    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/frame.py:414(__init__)
#        12    0.000    0.000    0.002    0.000 <ipython-input-274-c59bfe7bbe66>:339(new_ballots)
#         1    0.000    0.000    0.002    0.002 <ipython-input-274-c59bfe7bbe66>:297(to_count_dataframe)
#         1    0.000    0.000    0.002    0.002 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:213(init_dict)
# 1618/1202    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/utils/Utils.py:19(_f)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:56(arrays_to_mgr)
#         1    0.000    0.000    0.001    0.001 <ipython-input-274-c59bfe7bbe66>:200(get_condorcet)
#         2    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1252(fp_write)
#        12    0.000    0.000    0.001    0.000 <ipython-input-274-c59bfe7bbe66>:345(<listcomp>)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:101(cowinners_)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:77(order_)
#       380    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:362(__iter__)
#         3    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#       6/3    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:276(__new__)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1667(create_block_manager_from_arrays)
#         1    0.000    0.000    0.001    0.001 <ipython-input-274-c59bfe7bbe66>:310(to_ballot_dataframe)
#        32    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:75(__init__)
#         6    0.000    0.000    0.001    0.000 <ipython-input-274-c59bfe7bbe66>:283(to_count_matrix)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:80(<setcomp>)
#         1    0.000    0.000    0.001    0.001 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixMajority.py:92(as_dict_)
#        32    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:81(_parse)
#         8    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:5293(ensure_index)
#         7    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:98(__init__)
#        32    0.001    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:93(<listcomp>)
#         2    0.000    0.000    0.001    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:71(__call__)
#         7    0.000    0.000    0.001    0.000 <ipython-input-274-c59bfe7bbe66>:135(name_ballots)
#         7    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:137(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:123(init_ndarray)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/PopulationSpheroid.py:34(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:122(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:60(__init__)
#       400    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:158(__len__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:256(as_dict_)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1700(form_blocks)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:100(<listcomp>)
#        15    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:322(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:212(_rebuild_blknos_and_blklocs)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:76(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'randn' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:241(get_plurality)
#         3    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:119(rank_matrix)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:68(matrix_majority_)
#       400    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:340(_check_strict)
#   220/200    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/converter_ballot/ConverterBallotGeneral.py:90(__call__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:300(_homogenize)
#        83    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/utils/Utils.py:229(convert_number)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/construction.py:388(sanitize_array)
#        56    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/base.py:247(is_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:233(weights_)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1064(__repr__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:144(_gross_and_weights_)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1643(create_block_manager_from_blocks)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixMajority.py:75(matrix_weighted_majority_)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:310(format_meter)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:417(_get_axes)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/construction.py:506(_try_cast)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:3027(make_block)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:2981(get_block_type)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:107(<listcomp>)
#       241    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:10(_check)
#        47    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:1092(is_alive)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:74(<listcomp>)
#        60    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/converter_ballot/ConverterBallotToOrder.py:51(__call__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811(_multi_blockify)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:221(get_majority)
#       101    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:84(__new__)
#       600    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numeric.py:2283(_array_equal_dispatcher)
#        17    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:472(is_period_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:253(preferences_rk)
#        50    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1708(_is_dtype_type)
#        13    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:917(is_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:1612(preferences_ut_to_preferences_rk)
#       120    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:287(<listcomp>)
#       252    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:266(__getitem__)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(lexsort)
#        10    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_dtype.py:333(_name_get)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1209(maybe_cast_to_datetime)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:258(<dictcomp>)
#        32    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1565(is_extension_array_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixMajority.py:61(__init__)
#       381    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        12    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:987(is_datetime64_any_dtype)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/utils/Utils.py:253(my_division)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:82(<listcomp>)
#        17    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:506(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:260(get_candidate_rank_map)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:116(__init__)
#        26    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        47    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:1050(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1102(maybe_infer_to_datetimelike)
#        30    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        13    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:1124(is_dtype)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:499(__init__)
#        19    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:542(is_categorical_dtype)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:115(candidates_in_b)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(sum)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:118(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1088(maybe_castable)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:655(_consolidate_check)
#        16    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:403(is_datetime64tz_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:79(<listcomp>)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/common.py:219(asarray_tuplesafe)
#       346    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:540(_decr_instances)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2092(sum)
#        10    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:222(is_object_dtype)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:656(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:343(ftype)
#        89    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:2591(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:77(<listcomp>)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:323(is_strict)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:73(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:83(_check_profile)
#         8    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:372(is_datetime64_dtype)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:5463(_maybe_cast_data_without_dtype)
#        32    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:75(find)
#         1    0.000    0.000    0.000    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#       420    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:106(candidate_map)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:273(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:84(<listcomp>)
#        10    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_dtype.py:319(_name_includes_bit_suffix)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1828(_stack_arrays)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:347(as_strict_order)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:91(release)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:511(__new__)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:216(__init__)
#       284    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:117(ballots)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixMajority.py:99(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:5387(default_index)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:251(mgr_locs)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:329(_verify_integrity)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:87(acquire)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:339(is_categorical)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:88(_check_profile)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:39(__init__)
#        12    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:441(is_timedelta64_dtype)
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1435(is_bool_dtype)
#        67    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/converter_ballot/ConverterBallotGeneral.py:82(__init__)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixMajority.py:94(convert)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:227(format_interval)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:374(forward)
#         9    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:5393(maybe_extract_name)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:163(shape)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1458(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/Rule.py:89(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:95(__enter__)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:254(_is_ascii)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        15    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:309(_is_master_process)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numerictypes.py:365(issubdtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/range.py:83(__new__)
#       155    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_dtype.py:46(__str__)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:830(is_signed_integer_dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:53(__new__)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:423(_div)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:252(is_sparse)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:315(_environ_cols_linux)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:98(__exit__)
#        40    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/ipykernel/iostream.py:93(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_asarray.py:223(require)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:65(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(flatnonzero)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1402(format_dict)
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_methods.py:28(_amax)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:533(_get_free_pos)
#       106    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10be75568}
#         9    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:58(__iter__)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:472(_simple_new)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         6    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numeric.py:591(flatnonzero)
#         6    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_methods.py:44(_any)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:614(__gt__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:5409(_maybe_cast_with_dtype)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:127(candidates)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:146(candidates_not_in_b)
#       106    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:278(denominator)
#        36    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:206(classes)
#        36    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:208(<lambda>)
#        18    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1844(pandas_dtype)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:3911(__getitem__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:249(<listcomp>)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:360(<listcomp>)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:252(_acquire_restore)
#        10    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numerictypes.py:293(issubclass_)
#         5    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:775(is_integer_dtype)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1672(_get_dtype)
#        18    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:165(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:536(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:106(remove)
#       102    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:274(numerator)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:588(_richcmp)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_internal.py:830(npy_ctypes_check)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1401(is_float_dtype)
#        20    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:338(<listcomp>)
#        16    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:615(__len__)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:154(__format__)
#         6    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:289(<listcomp>)
#        12    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:346(<listcomp>)
#         9    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:102(n_candidates)
#        27    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        14    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:245(<genexpr>)
#        80    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:125(<genexpr>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:277(get_named_ballots)
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:243(__exit__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ravel)
#        14    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:216(<lambda>)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/construction.py:337(extract_array)
#         1    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:278(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/fractions.py:567(__eq__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/range.py:131(_simple_new)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1831(_asarray_compat)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:252(<listcomp>)
#        28    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:114(candidates)
#        64    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        47    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/os.py:676(__getitem__)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:240(__enter__)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:887(is_unsigned_integer_dtype)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/common.py:275(maybe_iterable_to_list)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/generic.py:190(__init__)
#        60    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:220(restrict)
#        63    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:249(_release_save)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:255(_is_owned)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1693(ravel)
#         3    0.000    0.000    0.000    0.000 {method 'union' of 'set' objects}
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:81(add)
#        48    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/threading.py:507(is_set)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(nonzero)
#         9    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:358(is_hashable)
#        40    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/ballot/BallotOrder.py:102(as_weak_order)
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         7    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_asarray.py:300(<setcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:128(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/construction.py:260(prep_ndarray)
#        15    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:20(__enter__)
#        10    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_dtype.py:36(_kind_name)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1804(nonzero)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:96(is_iterator)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:685(is_dtype_equal)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/cast.py:1483(construct_1d_ndarray_preserving_na)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/common.py:151(cast_scalar_indexer)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:592(_reset_identity)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:152(__eq__)
#        12    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:353(<listcomp>)
#        26    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         7    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/os.py:754(encode)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:55(_wrapfunc)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:179(ensure_python_int)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:1186(name)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:943(_consolidate_inplace)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:130(weights)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:145(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:287(status_printer)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:333(_term_move_up)
#         7    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         7    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#        14    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/dtypes/common.py:211(classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/common.py:183(all_none)
#         4    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:331(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Utils/MyLog.py:27(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:317(items)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:146(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:147(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:613(get_lock)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1061(__del__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1067(_comparable)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:1071(__hash__)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:135(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:247(_supports_unicode)
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method math.gcd}
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/_weakrefset.py:67(__len__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/multiarray.py:387(lexsort)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:74(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:4046(equals)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/range.py:675(__len__)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:129(_check_ndim)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:335(shape)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:232(items)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1837(_shape_compat)
#         7    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/profile/Profile.py:143(voters)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:81(<setcomp>)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:139(__format__)
#         3    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:384(<listcomp>)
#         3    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:110(n_voters)
#        22    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#         5    0.000    0.000    0.000    0.000 {built-in method time.time}
#         6    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/numeric.py:587(_flatnonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/_asarray.py:88(asanyarray)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2087(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:429(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/base.py:573(is_)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:83(_validate_dtype)
#         6    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:247(mgr_locs)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:167(ndim)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:647(is_consolidated)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/managers.py:1815(<lambda>)
#         3    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/utils/Utils.py:72(delete_cache)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/Matrix.py:55(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/matrix/MatrixWeightedMajority.py:218(gross_)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/whalrus/rule/RuleCondorcet.py:83(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/std.py:268(ema)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/_monitor.py:98(report)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:233(_is_utf)
#        60    0.000    0.000    0.000    0.000 <ipython-input-274-c59bfe7bbe66>:273(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1689(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/numpy/core/fromnumeric.py:1800(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:229(labels_candidates)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:238(V)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Preferences/Population.py:233(C)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/common.py:187(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/pandas/core/internals/blocks.py:339(dtype)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/svvamp/Utils/MyLog.py:36(_mylog)
#         1    0.000    0.000    0.000    0.000 /Users/dafirebanks/miniconda3/envs/dsci/lib/python3.7/site-packages/tqdm/utils.py:263(_environ_cols_wrapper)

# %% [markdown]
# ### Testing generated dataset code

# %%
test_preferences = dataset[0]
test_preferences.IM_rank_matrices[0]
# for preferences in dataset:
#     print(len(preferences.IM_rank_matrices[0]), "\n")
#     print(preferences.all_candidates_idx)
#     print(random.choice(profile.all_candidates_idx, 2), "\n")
# Out:
# [array([[ 5,  6,  9],
#         [10,  4,  6],
#         [ 5, 10,  5]]),
#  array([[5, 7, 8],
#         [9, 5, 6],
#         [6, 8, 6]]),
#  array([[ 4,  7,  9],
#         [11,  4,  5],
#         [ 5,  9,  6]]),
#  array([[ 6,  7,  7],
#         [10,  4,  6],
#         [ 4,  9,  7]])]

# %%
import timeit

# %%
timeit.timeit("np.random.choice(np.array(range(5)))", setup="import numpy as np", number=10000)
# Out:
# 0.3390418649996718

# %%
setup1 = """\
import numpy as np
test_list=np.array(list(range(10)))
"""

test1 = """\
np.random.choice(test_list, 2)
"""

timeit.timeit(test1, setup=setup1, number=100000)
# Out:
# 2.925066947000232

# %%
setup2 = """\
import random
test_list=list(range(10))
"""

test2 = """\
random.sample(test_list, 2)
"""

timeit.timeit(test2, setup=setup2, number=100000)
# Out:
# 0.44472726799995144

# %%
test3 = """\
random.choices(test_list, k=2)
"""

timeit.timeit(test3, setup=setup2, number=100000)
# Out:
# 0.2677106430001004

# %%
# Exclude candidate W from the list of candidates going up
        if option == 1:
            # C > O_1 > O_2 > W ===> C > O_2 > O_1 > W
            candidate_up = random.choice()
            
            
            candidate_up = random.choice(
                self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:])
            candidate_down = random.choice(
                self.all_candidates_idx[:candidate_up] + self.all_candidates_idx[candidate_up + 1:])

        # Select candidate W to go down
        elif option == 2:
            # C > W > O ===> C > O > W
            candidate_down = winner_idx
            candidate_up = random.choice(
                self.all_candidates_idx[:winner_idx] + self.all_candidates_idx[winner_idx + 1:])

        # Exclude candidate C from the list of candidates going down
        elif option == 3:
            candidate_down = random.choice(
                self.all_candidates_idx[:wanted_idx] + self.all_candidates_idx[wanted_idx + 1:])
            candidate_up = random.choice(
                self.all_candidates_idx[:candidate_down] + self.all_candidates_idx[candidate_down + 1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-118-8326433a1e5f> in <module>
#       1 # List of probabilities for a candidate to be chosen, it is uniform at the beginning
# ----> 2 probs = [1/(len(self.all_candidates_idx)-1)]*len(self.all_candidates_idx)
#       3
#       4 # Exclude candidate W from the list of candidates going up
#       5 # C > O_1 > O_2 > W ===> C > O_2 > O_1 > W
#
# NameError: name 'self' is not defined

# %%
rd.sample([5,6,7,8,9,10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-380c5f395e56> in <module>
# ----> 1 rd.sample([5,6,7,8,9,10])
#
# TypeError: sample() missing 1 required positional argument: 'k'
